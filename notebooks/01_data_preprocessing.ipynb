# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# This notebook's goal is to clean and preprocess the NHANES (August 2021 - August 2023) dataset to prepare it for use in a machine learning model aimed at predicting diabetes risk.

# %% [markdown]
# ### Key Columns
# SEQN - Respondent sequence number

# %% [markdown]
# ## Table of Contents
# 1. [Importing Libraries](#import-libraries)
# 2. [Loading the Dataset](#loading-the-dataset)
# 3. [Initial Data Exploration](#data-exploration)
# 4. [Data Cleaning](#data-cleaning)
# 5. [Data Preprocessing]()
# 6. [Exploratory Data Analysis (EDA)]#eda)

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
import sys
import os

# Import functions
notebook_dir = os.getcwd()
src_path = os.path.join(notebook_dir, '../src')
sys.path.append(src_path)
from data_cleaning import filter_columns

# %% [markdown]
# # Loading the dataset

# %%
folder_path = '../data/raw/csv_files/'

# list csv files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

merged_df = None
# Load each csv file into a pandas dataframe and merge on 'SEQN' column
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)

    if merged_df is None:
        merged_df = df
    else:
        merged_df = pd.merge(merged_df, df, on='SEQN', how='inner')

# %% [markdown]
# # Data Exploration

# %%
# Check merged dataframe structure
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6337 entries, 0 to 6336
# Data columns (total 80 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      6337 non-null   float64
#  1   ALQ111    5481 non-null   float64
#  2   ALQ121    4922 non-null   float64
#  3   ALQ130    4069 non-null   float64
#  4   ALQ142    4082 non-null   float64
#  5   ALQ270    2366 non-null   float64
#  6   ALQ280    2362 non-null   float64
#  7   ALQ151    4901 non-null   float64
#  8   ALQ170    2358 non-null   float64
#  9   BPQ020    6337 non-null   float64
#  10  BPQ030    2322 non-null   float64
#  11  BPQ150    2323 non-null   float64
#  12  BPQ080    6337 non-null   float64
#  13  BPQ101D   6337 non-null   float64
#  14  DBQ010    0 non-null      float64
#  15  DBD030    0 non-null      float64
#  16  DBD041    0 non-null      float64
#  17  DBD050    0 non-null      float64
#  18  DBD055    0 non-null      float64
#  19  DBD061    0 non-null      float64
#  20  DBQ073A   0 non-null      float64
#  21  DBQ073B   0 non-null      float64
#  22  DBQ073C   0 non-null      float64
#  23  DBQ073D   0 non-null      float64
#  24  DBQ073E   0 non-null      float64
#  25  DBQ073U   0 non-null      float64
#  26  DBQ301    2771 non-null   float64
#  27  DBQ330    2771 non-null   float64
#  28  DBQ360    272 non-null    float64
#  29  DBQ370    79 non-null     float64
#  30  DBD381    75 non-null     float64
#  31  DBQ390    53 non-null     float64
#  32  DBQ400    79 non-null     float64
#  33  DBD411    67 non-null     float64
#  34  DBQ421    35 non-null     float64
#  35  DBQ424    47 non-null     float64
#  36  DBQ930    6337 non-null   float64
#  37  DBQ935    6337 non-null   float64
#  38  DBQ940    6337 non-null   float64
#  39  DBQ945    6337 non-null   float64
#  40  DIQ010    6337 non-null   float64
#  41  DID040    870 non-null    float64
#  42  DIQ160    5242 non-null   float64
#  43  DIQ180    5466 non-null   float64
#  44  DIQ050    870 non-null    float64
#  45  DID060    278 non-null    float64
#  46  DIQ060U   269 non-null    float64
#  47  DIQ070    1807 non-null   float64
#  48  DPQ010    5519 non-null   float64
#  49  DPQ020    5518 non-null   float64
#  50  DPQ030    5516 non-null   float64
#  51  DPQ040    5514 non-null   float64
#  52  DPQ050    5513 non-null   float64
#  53  DPQ060    5510 non-null   float64
#  54  DPQ070    5508 non-null   float64
#  55  DPQ080    5508 non-null   float64
#  56  DPQ090    5506 non-null   float64
#  57  DPQ100    4167 non-null   float64
#  58  INDFMMPI  5051 non-null   float64
#  59  INDFMMPC  5817 non-null   float64
#  60  INQ300    5820 non-null   float64
#  61  IND310    2861 non-null   float64
#  62  PAD790Q   6330 non-null   float64
#  63  PAD790U   5031 non-null   object
#  64  PAD800    5031 non-null   float64
#  65  PAD810Q   6330 non-null   float64
#  66  PAD810U   2876 non-null   object
#  67  PAD820    2877 non-null   float64
#  68  PAD680    6331 non-null   float64
#  69  SMQ020    6335 non-null   float64
#  70  SMQ040    2518 non-null   float64
#  71  SMD641    191 non-null    float64
#  72  SMD650    912 non-null    float64
#  73  SMD100MN  912 non-null    float64
#  74  SMQ621    0 non-null      float64
#  75  SMD630    0 non-null      float64
#  76  SMAQUEX2  6337 non-null   float64
#  77  WTPH2YR   6337 non-null   float64
#  78  LBXTC     5717 non-null   float64
#  79  LBDTCSI   5717 non-null   float64
# dtypes: float64(78), object(2)
# memory usage: 3.9+ MB

# %%
# Show the first 5 rows of the merged dataframe
merged_df.head()
# Out:
#        SEQN  ALQ111  ALQ121  ALQ130  ALQ142  ALQ270  ALQ280  ALQ151  ALQ170  \
# 0  130378.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  130379.0     1.0     2.0     3.0     0.0     NaN     NaN     2.0     NaN
# 2  130380.0     1.0    10.0     1.0     0.0     NaN     NaN     2.0     NaN
# 3  130386.0     1.0     4.0     2.0    10.0     0.0    10.0     2.0     0.0
# 4  130387.0     1.0     0.0     NaN     NaN     NaN     NaN     2.0     NaN
#
#    BPQ020  ...  SMQ040  SMD641  SMD650  SMD100MN  SMQ621  SMD630  SMAQUEX2  \
# 0     1.0  ...     3.0     NaN     NaN       NaN     NaN     NaN       1.0
# 1     1.0  ...     3.0     NaN     NaN       NaN     NaN     NaN       1.0
# 2     2.0  ...     NaN     NaN     NaN       NaN     NaN     NaN       1.0
# 3     2.0  ...     3.0     NaN     NaN       NaN     NaN     NaN       1.0
# 4     1.0  ...     NaN     NaN     NaN       NaN     NaN     NaN       1.0
#
#         WTPH2YR  LBXTC  LBDTCSI
# 0  56042.129410  264.0     6.83
# 1  37435.705647  214.0     5.53
# 2  85328.844519  187.0     4.84
# 3  44526.214135  183.0     4.73
# 4  22746.296353  203.0     5.25
#
# [5 rows x 80 columns]

# %%
# Check for missing values
merged_df.isnull().sum()
# Out:
# SEQN           0
# ALQ111       856
# ALQ121      1415
# ALQ130      2268
# ALQ142      2255
#             ...
# SMD630      6337
# SMAQUEX2       0
# WTPH2YR        0
# LBXTC        620
# LBDTCSI      620
# Length: 80, dtype: int64

# %%
# Summary statistics
merged_df.describe()
# Out:
#                 SEQN       ALQ111       ALQ121       ALQ130       ALQ142  \
# count    6337.000000  5481.000000  4922.000000  4069.000000  4082.000000
# mean   136348.738362     1.109104     5.030679     5.842959     4.742283
# std      3439.132476     0.385114     4.314321    54.996448     7.326042
# min    130378.000000     1.000000     0.000000     1.000000     0.000000
# 25%    133337.000000     1.000000     2.000000     1.000000     0.000000
# 50%    136397.000000     1.000000     5.000000     2.000000     4.000000
# 75%    139310.000000     1.000000     8.000000     3.000000     9.000000
# max    142310.000000     9.000000    99.000000   999.000000    99.000000
#
#             ALQ270       ALQ280       ALQ151       ALQ170       BPQ020  ...  \
# count  2366.000000  2362.000000  4901.000000  2358.000000  6337.000000  ...
# mean      4.838123     3.545301     1.821261     4.396098     1.637841  ...
# std       7.785415     7.133496     0.458352    45.252453     0.516130  ...
# min       0.000000     0.000000     1.000000     0.000000     1.000000  ...
# 25%       0.000000     0.000000     2.000000     0.000000     1.000000  ...
# 50%       4.000000     0.000000     2.000000     1.000000     2.000000  ...
# 75%       9.000000     7.000000     2.000000     2.000000     2.000000  ...
# max      99.000000    99.000000     9.000000   999.000000     9.000000  ...
#
#             SMQ040      SMD641      SMD650    SMD100MN  SMQ621  SMD630  \
# count  2518.000000  191.000000  912.000000  912.000000     0.0     0.0
# mean      2.339952   14.015707   18.188596    0.418860     NaN     NaN
# std       0.901815   15.099835   80.499562    0.633839     NaN     NaN
# min       1.000000    0.000000    1.000000    0.000000     NaN     NaN
# 25%       1.000000    4.000000    5.000000    0.000000     NaN     NaN
# 50%       3.000000   12.000000   10.000000    0.000000     NaN     NaN
# 75%       3.000000   20.000000   20.000000    1.000000     NaN     NaN
# max       3.000000   99.000000  999.000000    9.000000     NaN     NaN
#
#        SMAQUEX2        WTPH2YR        LBXTC      LBDTCSI
# count    6337.0    6337.000000  5717.000000  5717.000000
# mean        1.0   40024.873091   186.974637     4.835153
# std         0.0   31504.418240    42.666181     1.103440
# min         1.0       0.000000    62.000000     1.600000
# 25%         1.0   19228.917397   157.000000     4.060000
# 50%         1.0   31687.062804   184.000000     4.760000
# 75%         1.0   50785.688486   213.000000     5.510000
# max         1.0  241728.857241   438.000000    11.330000
#
# [8 rows x 78 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Get rid of Irrelevant Columns

# %% [markdown]
# Columns to be used:

# %%
filtered_df = filter_columns(merged_df)
filtered_df.describe()
# Out:
#                 SEQN      LBDTCSI       DIQ010      DID040       DIQ160  \
# count    6337.000000  5717.000000  6337.000000  870.000000  5242.000000
# mean   136348.738362     4.835153     1.899006   65.454023     1.875811
# std      3439.132476     1.103440     0.412357  124.466982     0.452716
# min    130378.000000     1.600000     1.000000    6.000000     1.000000
# 25%    133337.000000     4.060000     2.000000   40.000000     2.000000
# 50%    136397.000000     4.760000     2.000000   50.000000     2.000000
# 75%    139310.000000     5.510000     2.000000   60.000000     2.000000
# max    142310.000000    11.330000     9.000000  999.000000     9.000000
#
#             DBQ930       DBQ940       DBQ945       BPQ020       BPQ080  ...  \
# count  6337.000000  6337.000000  6337.000000  6337.000000  6337.000000  ...
# mean      1.326180     1.326022     1.480511     1.637841     1.640997  ...
# std       0.468851     0.478126     0.508427     0.516130     0.734506  ...
# min       1.000000     1.000000     1.000000     1.000000     1.000000  ...
# 25%       1.000000     1.000000     1.000000     1.000000     1.000000  ...
# 50%       1.000000     1.000000     1.000000     2.000000     2.000000  ...
# 75%       2.000000     2.000000     2.000000     2.000000     2.000000  ...
# max       2.000000     9.000000     9.000000     9.000000     9.000000  ...
#
#             DPQ030       DPQ040       DPQ050       DPQ060       DPQ070  \
# count  5516.000000  5514.000000  5513.000000  5510.000000  5508.000000
# mean      0.793510     0.860174     0.504263     0.411071     0.394880
# std       1.003693     0.965127     0.860577     0.786979     0.767524
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     1.000000     0.000000     0.000000     0.000000
# 75%       1.000000     1.000000     1.000000     1.000000     1.000000
# max       9.000000     9.000000     9.000000     9.000000     9.000000
#
#             DPQ080       DPQ090       DPQ100       SMQ040      SMD641
# count  5508.000000  5506.000000  4167.000000  2518.000000  191.000000
# mean      0.216594     0.082092     0.479242     2.339952   14.015707
# std       0.685077     0.438164     0.740106     0.901815   15.099835
# min       0.000000     0.000000     0.000000     1.000000    0.000000
# 25%       0.000000     0.000000     0.000000     1.000000    4.000000
# 50%       0.000000     0.000000     0.000000     3.000000   12.000000
# 75%       0.000000     0.000000     1.000000     3.000000   20.000000
# max       9.000000     9.000000     9.000000     3.000000   99.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Handle Missing Values

# %% [markdown]
# ### Columns that are more than 50% null

# %%
total_rows = len(filtered_df)

# Count null values and count of values equal to 999 and 99 for each column
null_counts = filtered_df.isnull().sum()
more_null = (filtered_df == 999).sum()
nine_nine_null = (filtered_df == 99).sum()

cols_to_drop = []

for col in filtered_df.columns:
    if null_counts[col] > 0.5 * total_rows or more_null[col] > 0.5 * total_rows or nine_nine_null[col] > 0.5 * total_rows:
        cols_to_drop.append(col)

cols_to_drop
# Out:
# ['DID040', 'BPQ150', 'PAD810U', 'ALQ280', 'SMQ040', 'SMD641']

# %% [markdown]
# #### Columns with over half null values

# %% [markdown]
# 1. DID040: Age when first told you had diabetes
#     - Will be left as null as this likely means they do not have diabetes at all.
# 2. BPQ150: taking high blood pressure medication
#     - Missing values will be imputed with mode value.
# 3. PAD810U: Vigorous Leisure Time Physical Activity (LTPA) unit day/week/month/year
#     - Missing values could indivate respondents do not engage in this specific physical activity.
# 4. ALQ280: # of times 8+ drinks in 1 day/past 12 months
#     - Missing data with 0.
# 5.SMQ040: Do you now smoke cigarettes?
#     - Missing values are filled with 0 as it likely means they are non-smokers.
# 6. SMD641: # days smoked cigarettes during past 30 days
#     - Missing values are filled with 0 as it likely means they are non-smokers.

# %%
# Replace 99 and 999 with NaN
filtered_df.loc[:, :] = filtered_df.replace([99, 999], np.nan)

fill_vals = {
    'BPQ150': filtered_df['BPQ150'].mode()[0],
    'PAD810U': 0,
    'ALQ280': 0,
    'SMQ040': 0,
    'SMD641': 0 
}

filtered_df.loc[:, :] = filtered_df.fillna(value=fill_vals)

# %% [markdown]
# #### Percentage of Null Values in each Column

# %%
null_percentage = filtered_df.isnull().mean() * 100
null_percentage[null_percentage > 0]
# Out:
# LBDTCSI      9.783809
# DID040      86.507811
# DIQ160      17.279470
# PAD680       0.094682
# PAD790U     20.609121
# ALQ130      35.947609
# ALQ142      35.774026
# INDFMMPC     8.205776
# DPQ010      12.908316
# DPQ020      12.924097
# DPQ030      12.955657
# DPQ040      12.987218
# DPQ050      13.002998
# DPQ060      13.050339
# DPQ070      13.081900
# DPQ080      13.081900
# DPQ090      13.113461
# DPQ100      34.243333
# dtype: float64
